# %%
from pyspark import SparkContext, SparkConf

conf = SparkConf().setAppName('Count')
sc = SparkContext.getOrCreate(conf)

rdd = sc.textFile('./quiz3.txt')
rdd.collect()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/16 17:13:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/16 17:13:45 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# ['this mango company',
#  'cat mango ant animal laptop',
#  'chair switch mango am charger cover',
#  'animal any mango ant laptop laptop',
#  'this']

# %%
rdd.count()
# Out:
# 5

# %%
rdd.flatMap(lambda x: x.split(' ')).count()
# Out:
# 21

# %% [markdown]
# ## CountByValue

# %%
rdd.flatMap(lambda x: x.split(' ')).countByValue()
# Out:
# defaultdict(int,
#             {'this': 2,
#              'mango': 4,
#              'company': 1,
#              'cat': 1,
#              'ant': 2,
#              'animal': 2,
#              'laptop': 3,
#              'chair': 1,
#              'switch': 1,
#              'am': 1,
#              'charger': 1,
#              'cover': 1,
#              'any': 1})
