# %%
from pyspark.sql import functions as F, SparkSession

spark = SparkSession.builder.appName("Save as Text File").getOrCreate()
text_df = spark.read.text('/Volumes/workspace/default/volume/sample.txt')

# %%
text_df.write.text('/Volumes/workspace/default/volume/sample_out.txt')

# %%
word_count_df = text_df\
    .select(F.explode(F.split(F.col('value'), ' ')).alias('word'))\
    .groupBy('word').agg(F.count('*').alias('count'))

display(word_count_df)

# %%
word_count_df.write.parquet('/Volumes/workspace/default/volume/sample_out_parquet.parquet')
