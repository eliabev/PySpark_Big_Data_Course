# %%
from pyspark import SparkContext, SparkConf

conf = SparkConf().setAppName('Distinct')
sc = SparkContext.getOrCreate(conf=conf)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/15 11:31:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/15 11:31:55 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/04/15 11:31:55 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 26/04/15 11:31:55 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.

# %%
rdd = sc.textFile('./sample.txt')

distinct_rdd = rdd.distinct()
distinct_rdd.collect()
# Out:
# ['12 43 6 7 8', '12 12 33', '1 2 3 4 5', '3 4 5 66 77 ']

# %%
distinct_rdd = rdd.flatMap(lambda x: x.split(' ')).distinct()
distinct_rdd.collect()
# Out:
# ['1', '4', '66', '77', '', '12', '8', '33', '2', '3', '5', '43', '6', '7']
