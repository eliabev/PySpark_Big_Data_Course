# %%
from pyspark import SparkConf, SparkContext

conf = SparkConf().setAppName('Save as Text File')
sc = SparkContext.getOrCreate(conf)

rdd = sc.textFile('quiz3.txt')
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/16 17:36:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/16 17:36:03 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/04/16 17:36:03 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54343)
# Traceback (most recent call last):
#   File "/Users/eliabe/.pyenv/versions/3.9.1/lib/python3.9/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
# ...

# %%
"""
It won't create a text file, but a folder.
This folder will contain the result of all the partitions (2, in this case)
but not a single file result.
Spark already know how to read the data from this "folder"
"""
rdd.saveAsTextFile('./example.txt')
