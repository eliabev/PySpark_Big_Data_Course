# %%
from pyspark import SparkContext, SparkConf

conf = SparkConf().setAppName('Group By Key')
sc = SparkContext.getOrCreate(conf=conf)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/22 08:35:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/22 08:35:37 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
rdd = sc.textFile('./quiz2.txt')

rdd.map(lambda x: (x, len(x.split(' ')))).collect()
# Out:
# [('this mango company animal', 4),
#  ('cat dog ant mic laptop', 5),
#  ('chair switch mobile am charger cover', 6),
#  ('amanda any alarm ant', 4)]

# %%
rdd.flatMap(lambda x: x.split(" "))\
    .map(lambda x: (x, len(x)))\
    .groupByKey()\
    .mapValues(list)\
    .collect()
# Out:
# [('this', [4]),
#  ('mango', [5]),
#  ('cat', [3]),
#  ('ant', [3, 3]),
#  ('laptop', [6]),
#  ('chair', [5]),
#  ('switch', [6]),
#  ('mobile', [6]),
#  ('am', [2]),
#  ('company', [7]),
#  ('animal', [6]),
#  ('dog', [3]),
#  ('mic', [3]),
#  ('charger', [7]),
#  ('cover', [5]),
#  ('amanda', [6]),
#  ('any', [3]),
#  ('alarm', [5])]
