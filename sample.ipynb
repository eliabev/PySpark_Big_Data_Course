# %%
from pyspark import SparkConf, SparkContext

conf = SparkConf().setAppName("Read File")
sc = SparkContext.getOrCreate(conf=conf)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/13 15:28:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
text = sc.textFile('./sample.txt')

# %%
text.collect()
# Out:
# ['1 2 3 4 5', '3 4 5 66 77 ', '12 43 6 7 8', '12 12 33']

# %%
from pyspark.sql import SparkSession

sc = SparkSession.builder\
        .appName("PySpark Eli!!")\
        .getOrCreate()

# %%
rdd = sc.read.text('./sample.txt')

# %%
#!pip3 install pandas
#!pip3 install pyarrow
rdd.mapInPandas(lambda x: x, rdd.schema).show()
# Out:
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Downloading pyarrow-21.0.0-cp39-cp39-macosx_12_0_arm64.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 34.3 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-21.0.0
# [Stage 1:>                                                          (0 + 1) / 1]
# +------------+
# |       value|
# +------------+
# |   1 2 3 4 5|
# |3 4 5 66 77 |
# | 12 43 6 7 8|
# |    12 12 33|
# +------------+
